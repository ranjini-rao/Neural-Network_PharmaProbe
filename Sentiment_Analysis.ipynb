# %%
import pandas as pd

# Load the review embeddings CSV file into a DataFrame
embedded_df = pd.read_csv('embedded_review.csv')

# Display the first few rows of the DataFrame to verify it was loaded correctly
embedded_df.head()
# Out:
#    uniqueID                 drugName                     condition  \
# 0     95260               Guanfacine                          ADHD
# 1     92703                   Lybrel                 Birth Control
# 2    138000               Ortho Evra                 Birth Control
# 3     35696  Buprenorphine  naloxone             Opiate Dependence
# 4    155963                   Cialis  Benign Prostatic Hyperplasia
#
#                                               review  rating       date  \
# 0  My son is halfway through his fourth week of I...     8.0  27-Apr-10
# 1  I used to take another oral contraceptive whic...     5.0  14-Dec-09
# 2  This is my first time using any form of birth ...     8.0   3-Nov-15
# 3  Suboxone has completely turned my life around ...     9.0  27-Nov-16
# 4  2nd day on 5mg started to work with rock hard ...     2.0  28-Nov-15
#
#    usefulCount  lengthReview  conditionCluster_label  drugNameCluster_label  \
# 0        192.0         712.0                     2.0                    4.0
# 1         17.0         708.0                     9.0                    6.0
# 2         10.0         428.0                     9.0                    4.0
# 3         37.0         669.0                     0.0                    2.0
# 4         43.0         373.0                     0.0                    5.0
#
#    ...       758       759       760       761       762       763       764  \
# 0  ... -0.416409 -0.364040 -0.036060  0.383963  0.176255 -0.147201 -0.243359
# 1  ... -0.279307 -0.419729 -0.389261  0.328398  0.291834 -0.027217 -0.359790
# 2  ... -0.232733 -0.031823 -0.032784  0.188440  0.162272  0.363399 -0.096650
# 3  ... -0.310564 -0.599643 -0.375174  0.309915  0.577983  0.051811 -0.184821
# 4  ... -0.247983 -0.438636 -0.037911 -0.030183  0.508780  0.064493 -0.205261
#
#         765       766       767
# 0 -0.541467  0.062160  0.049585
# 1 -0.706709  0.047264 -0.017902
# 2 -0.693634 -0.024901  0.548486
# 3 -0.710691  0.065533  0.371945
# 4 -0.527391 -0.101341  0.039573
#
# [5 rows x 778 columns]

# %%
# Read the review_sentiment CSV
sentiment_df = pd.read_csv('reviews_sentiments.csv')

# Display the first few rows of the DataFrame to verify it was loaded correctly
sentiment_df.head()
# Out:
#    uniqueID                                             review sentiment
# 0     95260  My son is halfway through his fourth week of I...  POSITIVE
# 1     92703  I used to take another oral contraceptive whic...  NEGATIVE
# 2    138000  This is my first time using any form of birth ...  NEGATIVE
# 3     35696  Suboxone has completely turned my life around ...  POSITIVE
# 4    155963  2nd day on 5mg started to work with rock hard ...  NEGATIVE

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'orange', stopwords = stopwords, width = 1200, height = 800).generate(str(sentiment_df['review']))

plt.rcParams['figure.figsize'] = (15, 15)
plt.title('Word Cloud - Drug Names', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7907582a9780>

# %%
#update the sentiment labels

sentiment_df['sentiment'].replace('POSITIVE', 0, inplace =True)

sentiment_df['sentiment'].replace('NEGATIVE', 1, inplace =True)

sentiment_df['sentiment'].replace('NEUTRAL', 2, inplace =True)

sentiment_df.head()
# Out:
#    uniqueID                                             review  sentiment
# 0     95260  My son is halfway through his fourth week of I...          0
# 1     92703  I used to take another oral contraceptive whic...          1
# 2    138000  This is my first time using any form of birth ...          1
# 3     35696  Suboxone has completely turned my life around ...          0
# 4    155963  2nd day on 5mg started to work with rock hard ...          1

# %%
# Records for each sentiments.POstive and negative labels are almost balanced, but very few records with neutral label.
sentiment_df['sentiment'].value_counts()
# Out:
# 0    6294
# 1    4953
# 2      68
# Name: sentiment, dtype: int64

# %%
# drop the review column from sentiment_df
sentiment_df.drop('review', axis=1, inplace=True)

# %%
sentiment_df.head()
# Out:
#    uniqueID  sentiment
# 0     95260          0
# 1     92703          1
# 2    138000          1
# 3     35696          0
# 4    155963          1

# %%
embedded_sentiment_df = pd.merge(embedded_df, sentiment_df, on='uniqueID')

embedded_sentiment_df.head()
# Out:
#    uniqueID                 drugName                     condition  \
# 0     95260               Guanfacine                          ADHD
# 1     92703                   Lybrel                 Birth Control
# 2    138000               Ortho Evra                 Birth Control
# 3     35696  Buprenorphine  naloxone             Opiate Dependence
# 4    155963                   Cialis  Benign Prostatic Hyperplasia
#
#                                               review  rating       date  \
# 0  My son is halfway through his fourth week of I...     8.0  27-Apr-10
# 1  I used to take another oral contraceptive whic...     5.0  14-Dec-09
# 2  This is my first time using any form of birth ...     8.0   3-Nov-15
# 3  Suboxone has completely turned my life around ...     9.0  27-Nov-16
# 4  2nd day on 5mg started to work with rock hard ...     2.0  28-Nov-15
#
#    usefulCount  lengthReview  conditionCluster_label  drugNameCluster_label  \
# 0        192.0         712.0                     2.0                    4.0
# 1         17.0         708.0                     9.0                    6.0
# 2         10.0         428.0                     9.0                    4.0
# 3         37.0         669.0                     0.0                    2.0
# 4         43.0         373.0                     0.0                    5.0
#
#    ...       759       760       761       762       763       764       765  \
# 0  ... -0.364040 -0.036060  0.383963  0.176255 -0.147201 -0.243359 -0.541467
# 1  ... -0.419729 -0.389261  0.328398  0.291834 -0.027217 -0.359790 -0.706709
# 2  ... -0.031823 -0.032784  0.188440  0.162272  0.363399 -0.096650 -0.693634
# 3  ... -0.599643 -0.375174  0.309915  0.577983  0.051811 -0.184821 -0.710691
# 4  ... -0.438636 -0.037911 -0.030183  0.508780  0.064493 -0.205261 -0.527391
#
#         766       767  sentiment
# 0  0.062160  0.049585          0
# 1  0.047264 -0.017902          1
# 2 -0.024901  0.548486          1
# 3  0.065533  0.371945          0
# 4 -0.101341  0.039573          1
#
# [5 rows x 779 columns]

# %%
# Total number of records in the dataframe
len(embedded_sentiment_df)
# Out:
# 11315

# %%
# The NNet model classifies the sentiment as Postive, Negative and Neutral based on the review embeddings
# For now we are considering all the components

# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
embedded_sentiment_df.columns
# Out:
# Index(['uniqueID', 'drugName', 'condition', 'review', 'rating', 'date',
#        'usefulCount', 'lengthReview', 'conditionCluster_label',
#        'drugNameCluster_label',
#        ...
#        '759', '760', '761', '762', '763', '764', '765', '766', '767',
#        'sentiment'],
#       dtype='object', length=779)

# %%
# Drop all the columns that are not embeddings of the review and the sentiment labels.

columns_to_drop = ['uniqueID', 'drugName', 'condition', 'review', 'date', 'lengthReview', 'conditionCluster_label',
       'drugNameCluster_label']

embedded_sentiment770_df = embedded_sentiment_df.drop(columns=columns_to_drop)
embedded_sentiment770_df.head(5)
# Out:
#    rating  usefulCount         0         1         2         3         4  \
# 0     8.0        192.0 -0.010977  0.010914  0.200967 -0.229490 -0.535286
# 1     5.0         17.0  0.066320  0.189584  0.369006 -0.046920 -0.473988
# 2     8.0         10.0  0.084101 -0.019134  0.294494  0.029783 -0.228783
# 3     9.0         37.0  0.007820  0.207558  0.179105 -0.210057 -0.197015
# 4     2.0         43.0 -0.193177  0.360585  0.448292 -0.253824 -0.532782
#
#           5         6         7  ...       759       760       761       762  \
# 0  0.012419  0.578620  0.578304  ... -0.364040 -0.036060  0.383963  0.176255
# 1 -0.238288  0.341089  0.252703  ... -0.419729 -0.389261  0.328398  0.291834
# 2  0.170102  0.185404  0.210424  ... -0.031823 -0.032784  0.188440  0.162272
# 3  0.104799  0.338058  0.038666  ... -0.599643 -0.375174  0.309915  0.577983
# 4  0.085381  0.607802  0.260307  ... -0.438636 -0.037911 -0.030183  0.508780
#
#         763       764       765       766       767  sentiment
# 0 -0.147201 -0.243359 -0.541467  0.062160  0.049585          0
# 1 -0.027217 -0.359790 -0.706709  0.047264 -0.017902          1
# 2  0.363399 -0.096650 -0.693634 -0.024901  0.548486          1
# 3  0.051811 -0.184821 -0.710691  0.065533  0.371945          0
# 4  0.064493 -0.205261 -0.527391 -0.101341  0.039573          1
#
# [5 rows x 771 columns]

# %% [markdown]
# features - review embeddings, usefulCount, rating

# %%
# Split preprocessed data into features and target arrays

from keras.utils import to_categorical

# Separate the target variable
target = embedded_sentiment770_df['sentiment']

# Verify the unique values in the target variable
print(target.unique())

# Extract features (excluding the target variable)
features = embedded_sentiment770_df.drop(columns=['sentiment'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=30)

# Convert target labels to one-hot encoded format
y_train_encoded = to_categorical(y_train, num_classes=3)
y_test_encoded = to_categorical(y_test, num_classes=3)

# Check the shapes of the one-hot encoded target labels
print("Shape of y_train_encoded:", y_train_encoded.shape)
print("Shape of y_test_encoded:", y_test_encoded.shape)
# Out:
# [0 1 2]
# Shape of y_train_encoded: (7920, 3)
# Shape of y_test_encoded: (3395, 3)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Check the number of dimensions, make it a variable so it passes into

num_dimensions = embedded_sentiment770_df.shape[1]-1
print(num_dimensions)
# Out:
# 770

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# 3 classifications to predict now


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

nn = tf.keras.models.Sequential()

# Input layer
nn.add(tf.keras.layers.Dense(units=770, activation="sigmoid", input_dim=num_dimensions))

# Second hidden layer
nn.add(Dense(units=600, activation='relu'))

# Third hidden layer (example of adding an additional hidden layer)
nn.add(Dense(units=300, activation='relu'))

#Fourth hidden layer (example of adding another hidden layer)
nn.add(Dense(units=150, activation='relu'))

#Fifth hidden layer (example of adding another hidden layer)
nn.add(Dense(units=100, activation='relu'))

#Sixth hidden layer (example of adding another hidden layer)
nn.add(Dense(units=50, activation='relu'))

#Seventh hidden layer (example of adding another hidden layer)
nn.add(Dense(units=25, activation='relu'))

#Eighth hidden layer (example of adding another hidden layer)
nn.add(Dense(units=15, activation='relu'))

# Output layer
nn.add(Dense(units=3, activation='softmax'))  # 3 units for 3 classes, softmax activation

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_122 (Dense)           (None, 770)               593670
#
#  dense_123 (Dense)           (None, 600)               462600
#
#  dense_124 (Dense)           (None, 300)               180300
#
#  dense_125 (Dense)           (None, 150)               45150
#
#  dense_126 (Dense)           (None, 100)               15100
#
#  dense_127 (Dense)           (None, 50)                5050
#
#  dense_128 (Dense)           (None, 25)                1275
#
#  dense_129 (Dense)           (None, 15)                390
#
#  dense_130 (Dense)           (None, 3)                 48
#
# =================================================================
# Total params: 1303583 (4.97 MB)
# Trainable params: 1303583 (4.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model - the loss function is categorical and not for binary classification

# Define optimizer with custom learning rate
from tensorflow.keras.optimizers import Adam


custom_optimizer = Adam(learning_rate=0.001)

nn.compile(loss="categorical_crossentropy", optimizer=custom_optimizer, metrics=["accuracy"])

# %%
 # Fit the model to the training data
fit_model = nn.fit(X_train_scaled, y_train_encoded, epochs=10)
# Out:
# Epoch 1/10
# 248/248 [==============================] - 10s 24ms/step - loss: 0.6406 - accuracy: 0.6694
# Epoch 2/10
# 248/248 [==============================] - 5s 18ms/step - loss: 0.4975 - accuracy: 0.7785
# Epoch 3/10
# 248/248 [==============================] - 5s 18ms/step - loss: 0.4326 - accuracy: 0.8125
# Epoch 4/10
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3924 - accuracy: 0.8265
# Epoch 5/10
# 248/248 [==============================] - 5s 18ms/step - loss: 0.3608 - accuracy: 0.8453
# Epoch 6/10
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3187 - accuracy: 0.8665
# Epoch 7/10
# 248/248 [==============================] - 6s 23ms/step - loss: 0.2770 - accuracy: 0.8840
# Epoch 8/10
# 248/248 [==============================] - 5s 19ms/step - loss: 0.2187 - accuracy: 0.9131
# Epoch 9/10
# 248/248 [==============================] - 5s 22ms/step - loss: 0.1660 - accuracy: 0.9338
# Epoch 10/10
# 248/248 [==============================] - 5s 20ms/step - loss: 0.1179 - accuracy: 0.9578

# %%
test_loss, test_accuracy = nn.evaluate(X_test_scaled, y_test_encoded)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 107/107 [==============================] - 1s 5ms/step - loss: 0.9961 - accuracy: 0.7841
# Test Loss: 0.9961038827896118
# Test Accuracy: 0.7840942740440369

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# Define the model - deep neural net with L2 regularization
nn = Sequential()

# First hidden layer with L2 regularization
nn.add(Dense(units=770, activation="relu", kernel_regularizer=regularizers.l2(0.01), input_dim=num_dimensions))

# Second hidden layer with L2 regularization
nn.add(Dense(units=512, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Third hidden layer with L2 regularization
nn.add(Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Fourth hidden layer with L2 regularization
nn.add(Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Fifth hidden layer with L2 regularization
nn.add(Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Sixth hidden layer with L2 regularization
nn.add(Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Seventh hidden layer with L2 regularization
nn.add(Dense(units=64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Eighth hidden layer with L2 regularization
nn.add(Dense(units=64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Output layer
nn.add(Dense(units=3, activation='softmax'))

# Define optimizer with custom learning rate
custom_optimizer = Adam(learning_rate=0.001)

# Compile the model with the custom optimizer
nn.compile(loss="categorical_crossentropy", optimizer=custom_optimizer, metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn.fit(X_train_scaled, y_train_encoded, epochs=200)
# Out:
# Epoch 1/200
# 248/248 [==============================] - 8s 25ms/step - loss: 4.2810 - accuracy: 0.6631
# Epoch 2/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.8898 - accuracy: 0.7567
# Epoch 3/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.7408 - accuracy: 0.7870
# Epoch 4/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.6764 - accuracy: 0.7952
# Epoch 5/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.6217 - accuracy: 0.8051
# Epoch 6/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.5858 - accuracy: 0.8107
# Epoch 7/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.5680 - accuracy: 0.8273
# Epoch 8/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.5494 - accuracy: 0.8319
# Epoch 9/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.5374 - accuracy: 0.8346
# Epoch 10/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.5243 - accuracy: 0.8439
# Epoch 11/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.5245 - accuracy: 0.8452
# Epoch 12/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.5096 - accuracy: 0.8482
# Epoch 13/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.5008 - accuracy: 0.8573
# Epoch 14/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.5017 - accuracy: 0.8552
# Epoch 15/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4922 - accuracy: 0.8576
# Epoch 16/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4854 - accuracy: 0.8636
# Epoch 17/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4844 - accuracy: 0.8660
# Epoch 18/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4844 - accuracy: 0.8636
# Epoch 19/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.4756 - accuracy: 0.8688
# Epoch 20/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.4632 - accuracy: 0.8756
# Epoch 21/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4623 - accuracy: 0.8819
# Epoch 22/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4617 - accuracy: 0.8798
# Epoch 23/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4621 - accuracy: 0.8831
# Epoch 24/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4491 - accuracy: 0.8874
# Epoch 25/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4514 - accuracy: 0.8865
# Epoch 26/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4503 - accuracy: 0.8898
# Epoch 27/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.4493 - accuracy: 0.8900
# Epoch 28/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.4452 - accuracy: 0.8903
# Epoch 29/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4490 - accuracy: 0.8912
# Epoch 30/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4410 - accuracy: 0.8981
# Epoch 31/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4377 - accuracy: 0.9005
# Epoch 32/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.4359 - accuracy: 0.8984
# Epoch 33/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4362 - accuracy: 0.8990
# Epoch 34/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4212 - accuracy: 0.9049
# Epoch 35/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.4356 - accuracy: 0.9014
# Epoch 36/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.4257 - accuracy: 0.9056
# Epoch 37/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4312 - accuracy: 0.9011
# Epoch 38/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4276 - accuracy: 0.9071
# Epoch 39/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4189 - accuracy: 0.9102
# Epoch 40/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4123 - accuracy: 0.9149
# Epoch 41/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4191 - accuracy: 0.9097
# Epoch 42/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4120 - accuracy: 0.9126
# Epoch 43/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.4183 - accuracy: 0.9104
# Epoch 44/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.4042 - accuracy: 0.9178
# Epoch 45/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4104 - accuracy: 0.9131
# Epoch 46/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4162 - accuracy: 0.9097
# Epoch 47/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4079 - accuracy: 0.9162
# Epoch 48/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4105 - accuracy: 0.9140
# Epoch 49/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4119 - accuracy: 0.9124
# Epoch 50/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4076 - accuracy: 0.9174
# Epoch 51/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.4011 - accuracy: 0.9188
# Epoch 52/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.4033 - accuracy: 0.9167
# Epoch 53/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3965 - accuracy: 0.9232
# Epoch 54/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3961 - accuracy: 0.9202
# Epoch 55/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4047 - accuracy: 0.9145
# Epoch 56/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3986 - accuracy: 0.9242
# Epoch 57/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3930 - accuracy: 0.9255
# Epoch 58/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3938 - accuracy: 0.9256
# Epoch 59/200
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3997 - accuracy: 0.9218
# Epoch 60/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3915 - accuracy: 0.9270
# Epoch 61/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3931 - accuracy: 0.9245
# Epoch 62/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.4010 - accuracy: 0.9210
# Epoch 63/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3904 - accuracy: 0.9271
# Epoch 64/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.3982 - accuracy: 0.9208
# Epoch 65/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3943 - accuracy: 0.9237
# Epoch 66/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3898 - accuracy: 0.9270
# Epoch 67/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3791 - accuracy: 0.9335
# Epoch 68/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3968 - accuracy: 0.9210
# Epoch 69/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3898 - accuracy: 0.9255
# Epoch 70/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3891 - accuracy: 0.9292
# Epoch 71/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3886 - accuracy: 0.9279
# Epoch 72/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3857 - accuracy: 0.9270
# Epoch 73/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3893 - accuracy: 0.9255
# Epoch 74/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3757 - accuracy: 0.9346
# Epoch 75/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3881 - accuracy: 0.9292
# Epoch 76/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3866 - accuracy: 0.9309
# Epoch 77/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.3832 - accuracy: 0.9299
# Epoch 78/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3833 - accuracy: 0.9328
# Epoch 79/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3900 - accuracy: 0.9282
# Epoch 80/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3818 - accuracy: 0.9299
# Epoch 81/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.4096 - accuracy: 0.9206
# Epoch 82/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3783 - accuracy: 0.9332
# Epoch 83/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3838 - accuracy: 0.9285
# Epoch 84/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3808 - accuracy: 0.9311
# Epoch 85/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3830 - accuracy: 0.9311
# Epoch 86/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3822 - accuracy: 0.9332
# Epoch 87/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3767 - accuracy: 0.9332
# Epoch 88/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3907 - accuracy: 0.9266
# Epoch 89/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3799 - accuracy: 0.9330
# Epoch 90/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3790 - accuracy: 0.9318
# Epoch 91/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3816 - accuracy: 0.9297
# Epoch 92/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3762 - accuracy: 0.9332
# Epoch 93/200
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3740 - accuracy: 0.9347
# Epoch 94/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3927 - accuracy: 0.9236
# Epoch 95/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3791 - accuracy: 0.9318
# Epoch 96/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3890 - accuracy: 0.9274
# Epoch 97/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3732 - accuracy: 0.9338
# Epoch 98/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.3716 - accuracy: 0.9378
# Epoch 99/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3820 - accuracy: 0.9311
# Epoch 100/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3794 - accuracy: 0.9340
# Epoch 101/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3803 - accuracy: 0.9366
# Epoch 102/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3827 - accuracy: 0.9302
# Epoch 103/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3773 - accuracy: 0.9303
# Epoch 104/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3732 - accuracy: 0.9352
# Epoch 105/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3787 - accuracy: 0.9319
# Epoch 106/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3737 - accuracy: 0.9356
# Epoch 107/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.3843 - accuracy: 0.9292
# Epoch 108/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3834 - accuracy: 0.9304
# Epoch 109/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3805 - accuracy: 0.9335
# Epoch 110/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3814 - accuracy: 0.9331
# Epoch 111/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3741 - accuracy: 0.9365
# Epoch 112/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3773 - accuracy: 0.9351
# Epoch 113/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3655 - accuracy: 0.9404
# Epoch 114/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3828 - accuracy: 0.9328
# Epoch 115/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3765 - accuracy: 0.9335
# Epoch 116/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3768 - accuracy: 0.9352
# Epoch 117/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3774 - accuracy: 0.9347
# Epoch 118/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3763 - accuracy: 0.9352
# Epoch 119/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.3733 - accuracy: 0.9352
# Epoch 120/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3792 - accuracy: 0.9304
# Epoch 121/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3773 - accuracy: 0.9356
# Epoch 122/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3765 - accuracy: 0.9322
# Epoch 123/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3824 - accuracy: 0.9307
# Epoch 124/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3726 - accuracy: 0.9352
# Epoch 125/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3750 - accuracy: 0.9309
# Epoch 126/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3686 - accuracy: 0.9385
# Epoch 127/200
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3744 - accuracy: 0.9351
# Epoch 128/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3759 - accuracy: 0.9351
# Epoch 129/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3913 - accuracy: 0.9280
# Epoch 130/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3743 - accuracy: 0.9352
# Epoch 131/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3696 - accuracy: 0.9379
# Epoch 132/200
# 248/248 [==============================] - 5s 22ms/step - loss: 0.3735 - accuracy: 0.9350
# Epoch 133/200
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3759 - accuracy: 0.9336
# Epoch 134/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3701 - accuracy: 0.9364
# Epoch 135/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3642 - accuracy: 0.9404
# Epoch 136/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3772 - accuracy: 0.9316
# Epoch 137/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3767 - accuracy: 0.9338
# Epoch 138/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3706 - accuracy: 0.9354
# Epoch 139/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3741 - accuracy: 0.9342
# Epoch 140/200
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3789 - accuracy: 0.9304
# Epoch 141/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3640 - accuracy: 0.9428
# Epoch 142/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3767 - accuracy: 0.9361
# Epoch 143/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3686 - accuracy: 0.9409
# Epoch 144/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3716 - accuracy: 0.9348
# Epoch 145/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3836 - accuracy: 0.9314
# Epoch 146/200
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3737 - accuracy: 0.9345
# Epoch 147/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3773 - accuracy: 0.9364
# Epoch 148/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3707 - accuracy: 0.9386
# Epoch 149/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3816 - accuracy: 0.9304
# Epoch 150/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3587 - accuracy: 0.9408
# Epoch 151/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3711 - accuracy: 0.9385
# Epoch 152/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3793 - accuracy: 0.9362
# Epoch 153/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3800 - accuracy: 0.9333
# Epoch 154/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.3790 - accuracy: 0.9326
# Epoch 155/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3708 - accuracy: 0.9394
# Epoch 156/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3780 - accuracy: 0.9312
# Epoch 157/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3575 - accuracy: 0.9448
# Epoch 158/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3714 - accuracy: 0.9364
# Epoch 159/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3723 - accuracy: 0.9341
# Epoch 160/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3601 - accuracy: 0.9417
# Epoch 161/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3820 - accuracy: 0.9317
# Epoch 162/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3624 - accuracy: 0.9420
# Epoch 163/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3760 - accuracy: 0.9331
# Epoch 164/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3728 - accuracy: 0.9351
# Epoch 165/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3678 - accuracy: 0.9379
# Epoch 166/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3754 - accuracy: 0.9347
# Epoch 167/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3800 - accuracy: 0.9307
# Epoch 168/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3743 - accuracy: 0.9369
# Epoch 169/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3731 - accuracy: 0.9354
# Epoch 170/200
# 248/248 [==============================] - 5s 19ms/step - loss: 0.3672 - accuracy: 0.9378
# Epoch 171/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3639 - accuracy: 0.9372
# Epoch 172/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3779 - accuracy: 0.9348
# Epoch 173/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3771 - accuracy: 0.9330
# Epoch 174/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3659 - accuracy: 0.9374
# Epoch 175/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3653 - accuracy: 0.9398
# Epoch 176/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3629 - accuracy: 0.9384
# Epoch 177/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3751 - accuracy: 0.9332
# Epoch 178/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3618 - accuracy: 0.9443
# Epoch 179/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3686 - accuracy: 0.9379
# Epoch 180/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.3644 - accuracy: 0.9365
# Epoch 181/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3814 - accuracy: 0.9333
# Epoch 182/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3710 - accuracy: 0.9381
# Epoch 183/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3695 - accuracy: 0.9366
# Epoch 184/200
# 248/248 [==============================] - 5s 21ms/step - loss: 0.3712 - accuracy: 0.9359
# Epoch 185/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3651 - accuracy: 0.9405
# Epoch 186/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3767 - accuracy: 0.9317
# Epoch 187/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3655 - accuracy: 0.9371
# Epoch 188/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3699 - accuracy: 0.9347
# Epoch 189/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3616 - accuracy: 0.9391
# Epoch 190/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3650 - accuracy: 0.9372
# Epoch 191/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3697 - accuracy: 0.9381
# Epoch 192/200
# 248/248 [==============================] - 6s 22ms/step - loss: 0.3788 - accuracy: 0.9314
# Epoch 193/200
# 248/248 [==============================] - 6s 23ms/step - loss: 0.3750 - accuracy: 0.9356
# Epoch 194/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3691 - accuracy: 0.9357
# Epoch 195/200
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3664 - accuracy: 0.9403
# Epoch 196/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3687 - accuracy: 0.9374
# Epoch 197/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3717 - accuracy: 0.9366
# Epoch 198/200
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3787 - accuracy: 0.9350
# Epoch 199/200
# 248/248 [==============================] - 5s 20ms/step - loss: 0.3641 - accuracy: 0.9386
# Epoch 200/200
# 248/248 [==============================] - 6s 24ms/step - loss: 0.3626 - accuracy: 0.9390

# %%
test_loss, test_accuracy = nn.evaluate(X_test_scaled, y_test_encoded)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 107/107 [==============================] - 1s 5ms/step - loss: 0.8829 - accuracy: 0.7546
# Test Loss: 0.8828940391540527
# Test Accuracy: 0.7546391487121582

# %%
X_train_scaled.shape
# Out:
# (7920, 770)

# %%
y_train_encoded.shape
# Out:
# (7920, 3)

# %%
import numpy as np
#Get the test results from the above Neural Net

# Get predicted probabilities for each class
y_pred_probabilities = nn.predict(X_test_scaled)

# Convert probabilities to predicted classes by selecting the class with the highest probability
y_pred = np.argmax(y_pred_probabilities, axis=1)

# Convert one-hot encoded y_test_encoded back to categorical labels
y_test_categorical = np.argmax(y_test_encoded, axis=1)

# Create a DataFrame to compare predicted and actual classes
result_df = pd.DataFrame({'Actual': y_test_categorical, 'Predicted': y_pred})

# Add a column indicating whether the prediction was correct
result_df['Correct'] = result_df['Actual'] == result_df['Predicted']

# Display the DataFrame
print(result_df)

# Calculate accuracy manually
accuracy = result_df['Correct'].mean()
print("Manual Test Accuracy:", accuracy)
# Out:
# 107/107 [==============================] - 1s 7ms/step
#       Actual  Predicted  Correct
# 0          1          1     True
# 1          0          0     True
# 2          0          1    False
# 3          1          1     True
# 4          0          0     True
# ...      ...        ...      ...
# 3390       1          1     True
# 3391       1          1     True
# 3392       0          0     True
# 3393       0          0     True
# 3394       0          1    False
#
# [3395 rows x 3 columns]
# Manual Test Accuracy: 0.7546391752577319

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# Define the model-building function
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(units=hp.Int('units_input', min_value=64, max_value=800, step=64), activation='relu', input_dim=num_dimensions))
    for i in range(hp.Int('num_layers', 1, 8)):  # Number of hidden layers
        model.add(layers.Dense(units=hp.Int('units_' + str(i), min_value=64, max_value=512, step=64), activation='relu'))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
    return model

# Instantiate the tuner and perform hyperparameter search
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=3,
    directory='my_dir',
    project_name='helloworld')

tuner.search(X_train_scaled, y_train_encoded, epochs=5, validation_split=0.2)

# Get the best hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Optimal number of units in the input layer: {best_hps.get('units_input')}")
print(f"Optimal learning rate for the optimizer: {best_hps.get('learning_rate')}")
print(f"Optimal number of hidden layers: {best_hps.get('num_layers')}")
for i in range(best_hps.get('num_layers')):
    print(f"Optimal number of units in layer {i}: {best_hps.get('units_' + str(i))}")

# Build the model with the best hyperparameters and train it on the data
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train_scaled, y_train_encoded, epochs=50, validation_split=0.2)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test_scaled, y_test_encoded)
print("Test accuracy:", accuracy)
# Out:
# Reloading Tuner from my_dir/helloworld/tuner0.json
# Optimal number of units in the input layer: 768
# Optimal learning rate for the optimizer: 0.001
# Optimal number of hidden layers: 6
# Optimal number of units in layer 0: 448
# Optimal number of units in layer 1: 384
# Optimal number of units in layer 2: 512
# Optimal number of units in layer 3: 448
# Optimal number of units in layer 4: 384
# Optimal number of units in layer 5: 64
# Epoch 1/50
# 198/198 [==============================] - 8s 33ms/step - loss: 0.6387 - accuracy: 0.6776 - val_loss: 0.5837 - val_accuracy: 0.7481
# Epoch 2/50
# 198/198 [==============================] - 5s 23ms/step - loss: 0.4846 - accuracy: 0.7914 - val_loss: 0.5286 - val_accuracy: 0.7576
# Epoch 3/50
# 198/198 [==============================] - 5s 26ms/step - loss: 0.4048 - accuracy: 0.8253 - val_loss: 0.5310 - val_accuracy: 0.7898
# Epoch 4/50
# 198/198 [==============================] - 6s 29ms/step - loss: 0.3364 - accuracy: 0.8617 - val_loss: 0.5458 - val_accuracy: 0.7639
# Epoch 5/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.2922 - accuracy: 0.8801 - val_loss: 0.6451 - val_accuracy: 0.7620
# Epoch 6/50
# 198/198 [==============================] - 6s 31ms/step - loss: 0.2415 - accuracy: 0.9021 - val_loss: 0.5974 - val_accuracy: 0.7753
# Epoch 7/50
# 198/198 [==============================] - 5s 25ms/step - loss: 0.2145 - accuracy: 0.9151 - val_loss: 0.5780 - val_accuracy: 0.7790
# Epoch 8/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.1583 - accuracy: 0.9364 - val_loss: 0.7548 - val_accuracy: 0.7658
# Epoch 9/50
# 198/198 [==============================] - 6s 31ms/step - loss: 0.1430 - accuracy: 0.9478 - val_loss: 0.8316 - val_accuracy: 0.7841
# Epoch 10/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.1210 - accuracy: 0.9564 - val_loss: 0.7170 - val_accuracy: 0.7626
# Epoch 11/50
# 198/198 [==============================] - 5s 26ms/step - loss: 0.1145 - accuracy: 0.9612 - val_loss: 0.9314 - val_accuracy: 0.7645
# Epoch 12/50
# 198/198 [==============================] - 6s 28ms/step - loss: 0.1030 - accuracy: 0.9642 - val_loss: 0.9340 - val_accuracy: 0.7569
# Epoch 13/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0842 - accuracy: 0.9724 - val_loss: 1.2386 - val_accuracy: 0.7721
# Epoch 14/50
# 198/198 [==============================] - 6s 32ms/step - loss: 0.0835 - accuracy: 0.9684 - val_loss: 1.4127 - val_accuracy: 0.7677
# Epoch 15/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0793 - accuracy: 0.9740 - val_loss: 1.6240 - val_accuracy: 0.7759
# Epoch 16/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0677 - accuracy: 0.9776 - val_loss: 1.2898 - val_accuracy: 0.7822
# Epoch 17/50
# 198/198 [==============================] - 6s 31ms/step - loss: 0.0343 - accuracy: 0.9894 - val_loss: 1.2798 - val_accuracy: 0.7702
# Epoch 18/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0361 - accuracy: 0.9872 - val_loss: 1.5208 - val_accuracy: 0.7753
# Epoch 19/50
# 198/198 [==============================] - 6s 29ms/step - loss: 0.0544 - accuracy: 0.9807 - val_loss: 1.6667 - val_accuracy: 0.7727
# Epoch 20/50
# 198/198 [==============================] - 5s 27ms/step - loss: 0.0538 - accuracy: 0.9822 - val_loss: 2.0789 - val_accuracy: 0.7601
# Epoch 21/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0816 - accuracy: 0.9765 - val_loss: 1.4573 - val_accuracy: 0.7734
# Epoch 22/50
# 198/198 [==============================] - 6s 32ms/step - loss: 0.0315 - accuracy: 0.9885 - val_loss: 1.9574 - val_accuracy: 0.7683
# Epoch 23/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0422 - accuracy: 0.9867 - val_loss: 1.3624 - val_accuracy: 0.7727
# Epoch 24/50
# 198/198 [==============================] - 5s 25ms/step - loss: 0.0213 - accuracy: 0.9923 - val_loss: 2.0585 - val_accuracy: 0.7784
# Epoch 25/50
# 198/198 [==============================] - 6s 30ms/step - loss: 0.0323 - accuracy: 0.9899 - val_loss: 1.5275 - val_accuracy: 0.7797
# Epoch 26/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0351 - accuracy: 0.9885 - val_loss: 1.4808 - val_accuracy: 0.7702
# Epoch 27/50
# 198/198 [==============================] - 6s 31ms/step - loss: 0.0201 - accuracy: 0.9946 - val_loss: 2.1641 - val_accuracy: 0.7645
# Epoch 28/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0556 - accuracy: 0.9834 - val_loss: 1.2170 - val_accuracy: 0.7778
# Epoch 29/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0528 - accuracy: 0.9822 - val_loss: 1.4617 - val_accuracy: 0.7765
# Epoch 30/50
# 198/198 [==============================] - 6s 31ms/step - loss: 0.0215 - accuracy: 0.9929 - val_loss: 1.6470 - val_accuracy: 0.7771
# Epoch 31/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0159 - accuracy: 0.9953 - val_loss: 2.0221 - val_accuracy: 0.7778
# Epoch 32/50
# 198/198 [==============================] - 5s 26ms/step - loss: 0.0390 - accuracy: 0.9875 - val_loss: 0.9579 - val_accuracy: 0.7740
# Epoch 33/50
# 198/198 [==============================] - 6s 29ms/step - loss: 0.0593 - accuracy: 0.9839 - val_loss: 1.3910 - val_accuracy: 0.7765
# Epoch 34/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0482 - accuracy: 0.9875 - val_loss: 1.7378 - val_accuracy: 0.7708
# Epoch 35/50
# 198/198 [==============================] - 6s 32ms/step - loss: 0.0423 - accuracy: 0.9891 - val_loss: 2.0034 - val_accuracy: 0.7702
# Epoch 36/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0316 - accuracy: 0.9912 - val_loss: 1.5637 - val_accuracy: 0.7664
# Epoch 37/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0193 - accuracy: 0.9943 - val_loss: 2.1271 - val_accuracy: 0.7595
# Epoch 38/50
# 198/198 [==============================] - 6s 32ms/step - loss: 0.0158 - accuracy: 0.9956 - val_loss: 2.1451 - val_accuracy: 0.7683
# Epoch 39/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0258 - accuracy: 0.9910 - val_loss: 1.3281 - val_accuracy: 0.7715
# Epoch 40/50
# 198/198 [==============================] - 6s 28ms/step - loss: 0.0359 - accuracy: 0.9888 - val_loss: 1.6744 - val_accuracy: 0.7664
# Epoch 41/50
# 198/198 [==============================] - 5s 27ms/step - loss: 0.0260 - accuracy: 0.9923 - val_loss: 1.5471 - val_accuracy: 0.7803
# Epoch 42/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0272 - accuracy: 0.9926 - val_loss: 1.3015 - val_accuracy: 0.7721
# Epoch 43/50
# 198/198 [==============================] - 6s 32ms/step - loss: 0.0634 - accuracy: 0.9785 - val_loss: 1.4328 - val_accuracy: 0.7557
# Epoch 44/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0570 - accuracy: 0.9822 - val_loss: 1.7829 - val_accuracy: 0.7854
# Epoch 45/50
# 198/198 [==============================] - 5s 26ms/step - loss: 0.0362 - accuracy: 0.9886 - val_loss: 1.7522 - val_accuracy: 0.7753
# Epoch 46/50
# 198/198 [==============================] - 6s 29ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 1.4736 - val_accuracy: 0.7670
# Epoch 47/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0153 - accuracy: 0.9954 - val_loss: 1.5352 - val_accuracy: 0.7588
# Epoch 48/50
# 198/198 [==============================] - 6s 32ms/step - loss: 0.0173 - accuracy: 0.9937 - val_loss: 5.2348 - val_accuracy: 0.7822
# Epoch 49/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0227 - accuracy: 0.9934 - val_loss: 3.9614 - val_accuracy: 0.7677
# Epoch 50/50
# 198/198 [==============================] - 5s 24ms/step - loss: 0.0347 - accuracy: 0.9905 - val_loss: 1.7331 - val_accuracy: 0.7601
# 107/107 [==============================] - 1s 6ms/step - loss: 1.9423 - accuracy: 0.7596
# Test accuracy: 0.7596465349197388

# %%
# Redefine the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# 3 classifications to predict now


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

nn = tf.keras.models.Sequential()

# Input layer
nn.add(tf.keras.layers.Dense(units=768, activation="sigmoid", input_dim=num_dimensions))

# First hidden layer
nn.add(Dense(units=448, activation='relu'))

# Second hidden layer (example of adding an additional hidden layer)
nn.add(Dense(units=384, activation='relu'))

# Third hidden layer (example of adding an additional hidden layer)
nn.add(Dense(units=512, activation='relu'))

#Fourth hidden layer (example of adding another hidden layer)
nn.add(Dense(units=448, activation='relu'))

# Fifth hidden layer (example of adding an additional hidden layer)
nn.add(Dense(units=384, activation='relu'))

# Sixth hidden layer (example of adding an additional hidden layer)
nn.add(Dense(units=64, activation='relu'))

# Output layer
nn.add(Dense(units=3, activation='softmax'))  # 3 units for 3 classes, softmax activation

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_131 (Dense)           (None, 768)               592128
#
#  dense_132 (Dense)           (None, 448)               344512
#
#  dense_133 (Dense)           (None, 384)               172416
#
#  dense_134 (Dense)           (None, 512)               197120
#
#  dense_135 (Dense)           (None, 448)               229824
#
#  dense_136 (Dense)           (None, 384)               172416
#
#  dense_137 (Dense)           (None, 64)                24640
#
#  dense_138 (Dense)           (None, 3)                 195
#
# =================================================================
# Total params: 1733251 (6.61 MB)
# Trainable params: 1733251 (6.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model - the loss function is categorical and not for binary classification

# Define optimizer with custom learning rate
custom_optimizer = Adam(learning_rate=0.001)

nn.compile(loss="categorical_crossentropy", optimizer=custom_optimizer, metrics=["accuracy"])

# %%
 # Fit the model to the training data
fit_model = nn.fit(X_train_scaled, y_train_encoded, epochs=10)
# Out:
# Epoch 1/10
# 248/248 [==============================] - 9s 29ms/step - loss: 0.6484 - accuracy: 0.6633
# Epoch 2/10
# 248/248 [==============================] - 6s 23ms/step - loss: 0.5105 - accuracy: 0.7698
# Epoch 3/10
# 248/248 [==============================] - 7s 29ms/step - loss: 0.4436 - accuracy: 0.8091
# Epoch 4/10
# 248/248 [==============================] - 6s 23ms/step - loss: 0.4003 - accuracy: 0.8271
# Epoch 5/10
# 248/248 [==============================] - 7s 27ms/step - loss: 0.3698 - accuracy: 0.8410
# Epoch 6/10
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3332 - accuracy: 0.8587
# Epoch 7/10
# 248/248 [==============================] - 7s 28ms/step - loss: 0.2834 - accuracy: 0.8814
# Epoch 8/10
# 248/248 [==============================] - 7s 29ms/step - loss: 0.2254 - accuracy: 0.9077
# Epoch 9/10
# 248/248 [==============================] - 6s 25ms/step - loss: 0.1896 - accuracy: 0.9229
# Epoch 10/10
# 248/248 [==============================] - 7s 30ms/step - loss: 0.1434 - accuracy: 0.9462

# %%
test_loss, test_accuracy = nn.evaluate(X_test_scaled, y_test_encoded)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 107/107 [==============================] - 1s 7ms/step - loss: 0.7595 - accuracy: 0.7820
# Test Loss: 0.7595168352127075
# Test Accuracy: 0.7820324301719666
